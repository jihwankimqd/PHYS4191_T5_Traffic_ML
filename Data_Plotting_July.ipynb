# %%
import pandas as pd
import numpy as np

# %%
March_05 = pd.read_csv('July_02_FullData.csv')
March_12 = pd.read_csv('July_09_FullData.csv')
March_19 = pd.read_csv('July_16_FullData.csv')
March_26 = pd.read_csv('July_23_FullData.csv')
March_30 = pd.read_csv('July_30_FullData.csv')

# %%
March_05.head()
# Out:
#    Unnamed: 0   0                    1         2                    3  \
# 0           0  32  2020-07-02 00:06:30  01F3686S  2020-07-02 00:06:30
# 1           1  32  2020-07-02 00:21:23  03F4168S  2020-07-02 00:24:39
# 2           2  31  2020-07-02 00:51:18  01F2483S  2020-07-02 00:53:09
# 3           3  31  2020-07-02 00:02:13  03F2100S  2020-07-02 00:11:48
# 4           4  31  2020-07-02 00:51:19  03F2153N  2020-07-02 00:53:12
#
#           4     5  6                                                  7
# 0  01F3686S   2.2  Y                       2020-07-02 00:06:30+01F3686S
# 1  03F4232S   9.3  Y  2020-07-02 00:21:23+03F4168S; 2020-07-02 00:24...
# 2  01F2514S  13.4  Y  2020-07-02 00:51:18+01F2483S; 2020-07-02 00:53...
# 3  03F2261S  19.6  Y  2020-07-02 00:02:13+03F2100S; 2020-07-02 00:04...
# 4  03F2125N   5.9  Y  2020-07-02 00:51:19+03F2153N; 2020-07-02 00:53...

# %%
# Check column names and drop the first column ('Unnamed: 0').

March_05.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
March_05.drop(columns=['Unnamed: 0'],inplace=True)
March_12.drop(columns=['Unnamed: 0'],inplace=True)
March_19.drop(columns=['Unnamed: 0'],inplace=True)
March_26.drop(columns=['Unnamed: 0'],inplace=True)
March_30.drop(columns=['Unnamed: 0'],inplace=True)

# %%
March_05.head()
# Out:
#     0                    1         2                    3         4     5  6  \
# 0  32  2020-07-02 00:06:30  01F3686S  2020-07-02 00:06:30  01F3686S   2.2  Y
# 1  32  2020-07-02 00:21:23  03F4168S  2020-07-02 00:24:39  03F4232S   9.3  Y
# 2  31  2020-07-02 00:51:18  01F2483S  2020-07-02 00:53:09  01F2514S  13.4  Y
# 3  31  2020-07-02 00:02:13  03F2100S  2020-07-02 00:11:48  03F2261S  19.6  Y
# 4  31  2020-07-02 00:51:19  03F2153N  2020-07-02 00:53:12  03F2125N   5.9  Y
#
#                                                    7
# 0                       2020-07-02 00:06:30+01F3686S
# 1  2020-07-02 00:21:23+03F4168S; 2020-07-02 00:24...
# 2  2020-07-02 00:51:18+01F2483S; 2020-07-02 00:53...
# 3  2020-07-02 00:02:13+03F2100S; 2020-07-02 00:04...
# 4  2020-07-02 00:51:19+03F2153N; 2020-07-02 00:53...

# %%
# Only interested in data between 01F0339S and 01F0509S. Therefore, filter out irrelevant data.

March_05 = March_05[March_05["2"].str.contains("339S", na=False)]
March_05 = March_05[March_05["4"].str.contains("509S", na=False)]

March_12 = March_12[March_12["2"].str.contains("339S", na=False)]
March_12 = March_12[March_12["4"].str.contains("509S", na=False)]

March_19 = March_19[March_19["2"].str.contains("339S", na=False)]
March_19 = March_19[March_19["4"].str.contains("509S", na=False)]

March_26 = March_26[March_26["2"].str.contains("339S", na=False)]
March_26 = March_26[March_26["4"].str.contains("509S", na=False)]

March_30 = March_30[March_30["2"].str.contains("339S", na=False)]
March_30 = March_30[March_30["4"].str.contains("509S", na=False)]

# %%
March_05.head()
# Out:
#        0                    1         2                    3         4     5  \
# 295   31  2020-07-02 00:57:13  01F0339S  2020-07-02 01:06:31  01F0509S  19.4
# 493   31  2020-07-02 00:52:46  01F0339S  2020-07-02 01:02:41  01F0509S  19.4
# 1865  31  2020-07-02 00:49:49  01F0339S  2020-07-02 01:00:12  01F0509S  19.4
# 2013  32  2020-07-02 00:16:21  01F0339S  2020-07-02 00:27:38  01F0509S  19.4
# 2442  32  2020-07-02 00:08:18  01F0339S  2020-07-02 00:18:20  01F0509S  19.4
#
#       6                                                  7
# 295   Y  2020-07-02 00:57:13+01F0339S; 2020-07-02 00:59...
# 493   Y  2020-07-02 00:52:46+01F0339S; 2020-07-02 00:55...
# 1865  Y  2020-07-02 00:49:49+01F0339S; 2020-07-02 00:52...
# 2013  Y  2020-07-02 00:16:21+01F0339S; 2020-07-02 00:18...
# 2442  Y  2020-07-02 00:08:18+01F0339S; 2020-07-02 00:10...

# %%
March_12.head()
# Out:
#        0                    1         2                    3         4     5  \
# 2082  31  2020-07-09 00:08:22  01F0339S  2020-07-09 00:15:00  01F0509S  19.4
# 2374  31  2020-07-09 00:28:16  01F0339S  2020-07-09 00:38:26  01F0509S  19.4
# 4125  31  2020-07-09 00:20:17  01F0339S  2020-07-09 00:31:16  01F0509S  19.4
# 4934  31  2020-07-09 00:48:35  01F0339S  2020-07-09 00:59:36  01F0509S  19.4
# 5703  32  2020-07-09 00:45:05  01F0339S  2020-07-09 00:56:16  01F0509S  19.4
#
#       6                                                  7
# 2082  Y  2020-07-09 00:08:22+01F0339S; 2020-07-09 00:09...
# 2374  Y  2020-07-09 00:28:16+01F0339S; 2020-07-09 00:30...
# 4125  Y  2020-07-09 00:20:17+01F0339S; 2020-07-09 00:22...
# 4934  Y  2020-07-09 00:48:35+01F0339S; 2020-07-09 00:51...
# 5703  Y  2020-07-09 00:45:05+01F0339S; 2020-07-09 00:47...

# %%
March_19.head()
# Out:
#        0                    1         2                    3         4     5  \
# 137   31  2020-07-16 00:37:49  01F0339S  2020-07-16 00:48:17  01F0509S  19.4
# 2156  31  2020-07-16 00:11:37  01F0339S  2020-07-16 00:21:55  01F0509S  19.4
# 3263  31  2020-07-16 00:36:54  01F0339S  2020-07-16 00:48:54  01F0509S  19.4
# 4026  31  2020-07-16 00:43:32  01F0339S  2020-07-16 00:53:55  01F0509S  19.4
# 4735   5  2020-07-16 00:36:42  01F0339S  2020-07-16 00:49:15  01F0509S  19.4
#
#       6                                                  7
# 137   Y  2020-07-16 00:37:49+01F0339S; 2020-07-16 00:40...
# 2156  Y  2020-07-16 00:11:37+01F0339S; 2020-07-16 00:13...
# 3263  Y  2020-07-16 00:36:54+01F0339S; 2020-07-16 00:39...
# 4026  Y  2020-07-16 00:43:32+01F0339S; 2020-07-16 00:45...
# 4735  Y  2020-07-16 00:36:42+01F0339S; 2020-07-16 00:39...

# %%
March_26.head()
# Out:
#        0                    1         2                    3         4     5  \
# 2745  31  2020-07-23 00:10:31  01F0339S  2020-07-23 00:18:46  01F0509S  19.4
# 2934  32  2020-07-23 00:19:14  01F0339S  2020-07-23 00:30:36  01F0509S  19.4
# 3338  32  2020-07-23 00:01:01  01F0339S  2020-07-23 00:11:22  01F0509S  19.4
# 3996  32  2020-07-23 00:14:11  01F0339S  2020-07-23 00:24:25  01F0509S  19.4
# 4563  31  2020-07-23 00:46:57  01F0339S  2020-07-23 00:56:54  01F0509S  19.4
#
#       6                                                  7
# 2745  Y  2020-07-23 00:10:31+01F0339S; 2020-07-23 00:12...
# 2934  Y  2020-07-23 00:19:14+01F0339S; 2020-07-23 00:22...
# 3338  Y  2020-07-23 00:01:01+01F0339S; 2020-07-23 00:03...
# 3996  Y  2020-07-23 00:14:11+01F0339S; 2020-07-23 00:16...
# 4563  Y  2020-07-23 00:46:57+01F0339S; 2020-07-23 00:49...

# %%
total_data_rows = March_05.shape[0]+March_12.shape[0]+March_19.shape[0]+March_26.shape[0]+March_30.shape[0]
print('Total Rows of Data: '+str(total_data_rows))
# Out:
# Total Rows of Data: 15839

# %%
# Combine into one dataframe

df = pd.concat([March_05,March_12,March_19,March_26,March_30], ignore_index=True)
df.shape
# Out:
# (15839, 8)

# %%
# Save the cleaned raw data file as a csv file.

df.to_csv('Cleaned_Raw_Data.csv')

# %%
import re

example = df['7']
example
# Out:
# 0        2020-07-02 00:57:13+01F0339S; 2020-07-02 00:59...
# 1        2020-07-02 00:52:46+01F0339S; 2020-07-02 00:55...
# 2        2020-07-02 00:49:49+01F0339S; 2020-07-02 00:52...
# 3        2020-07-02 00:16:21+01F0339S; 2020-07-02 00:18...
# 4        2020-07-02 00:08:18+01F0339S; 2020-07-02 00:10...
# 5        2020-07-02 00:02:10+01F0339S; 2020-07-02 00:04...
# 6        2020-07-02 00:37:34+01F0339S; 2020-07-02 00:39...
# 7        2020-07-02 00:02:47+01F0339S; 2020-07-02 00:05...
# 8        2020-07-02 00:16:19+01F0339S; 2020-07-02 00:18...
# 9        2020-07-02 00:12:40+01F0339S; 2020-07-02 00:15...
# 10       2020-07-02 00:43:06+01F0339S; 2020-07-02 00:44...
# 11       2020-07-02 00:31:35+01F0339S; 2020-07-02 00:34...
# 12       2020-07-02 00:13:44+01F0339S; 2020-07-02 00:15...
# 13       2020-07-02 00:46:36+01F0339S; 2020-07-02 00:48...
# 14       2020-07-02 00:59:50+01F0339S; 2020-07-02 01:02...
# 15       2020-07-02 00:58:37+01F0339S; 2020-07-02 01:01...
# 16       2020-07-02 00:53:54+01F0339S; 2020-07-02 00:55...
# 17       2020-07-02 00:33:20+01F0339S; 2020-07-02 00:35...
# 18       2020-07-02 00:42:22+01F0339S; 2020-07-02 00:45...
# 19       2020-07-02 00:47:02+01F0339S; 2020-07-02 00:49...
# 20       2020-07-02 00:38:33+01F0339S; 2020-07-02 00:40...
# 21       2020-07-02 00:08:19+01F0339S; 2020-07-02 00:10...
# 22       2020-07-02 00:23:40+01F0339S; 2020-07-02 00:25...
# 23       2020-07-02 00:22:17+01F0339S; 2020-07-02 00:24...
# 24       2020-07-02 00:08:59+01F0339S; 2020-07-02 00:10...
# 25       2020-07-02 00:12:48+01F0339S; 2020-07-02 00:15...
# 26       2020-07-02 00:00:29+01F0339S; 2020-07-02 00:02...
# 27       2020-07-02 00:24:39+01F0339S; 2020-07-02 00:27...
# 28       2020-07-02 00:34:17+01F0339S; 2020-07-02 00:35...
# 29       2020-07-02 01:08:33+01F0339S; 2020-07-02 01:10...
#                                ...
# 15809    2020-07-30 23:23:14+01F0339S; 2020-07-30 23:25...
# 15810    2020-07-30 23:56:27+01F0339S; 2020-07-30 23:58...
# 15811    2020-07-30 23:42:07+01F0339S; 2020-07-30 23:44...
# 15812    2020-07-30 23:04:27+01F0339S; 2020-07-30 23:06...
# 15813    2020-07-30 23:25:59+01F0339S; 2020-07-30 23:28...
# 15814    2020-07-30 23:20:38+01F0339S; 2020-07-30 23:23...
# 15815    2020-07-30 23:38:16+01F0339S; 2020-07-30 23:40...
# 15816    2020-07-30 23:49:56+01F0339S; 2020-07-30 23:52...
# 15817    2020-07-30 23:47:14+01F0339S; 2020-07-30 23:49...
# 15818    2020-07-30 23:15:06+01F0339S; 2020-07-30 23:17...
# 15819    2020-07-30 23:22:37+01F0339S; 2020-07-30 23:25...
# 15820    2020-07-30 23:53:19+01F0339S; 2020-07-30 23:55...
# 15821    2020-07-30 23:58:43+01F0339S; 2020-07-31 00:00...
# 15822    2020-07-30 23:22:44+01F0339S; 2020-07-30 23:25...
# 15823    2020-07-30 23:36:21+01F0339S; 2020-07-30 23:38...
# 15824    2020-07-30 23:17:46+01F0339S; 2020-07-30 23:20...
# 15825    2020-07-30 23:58:55+01F0339S; 2020-07-31 00:01...
# 15826    2020-07-30 23:24:53+01F0339S; 2020-07-30 23:27...
# 15827    2020-07-30 23:04:07+01F0339S; 2020-07-30 23:06...
# 15828    2020-07-30 23:02:57+01F0339S; 2020-07-30 23:05...
# 15829    2020-07-30 23:30:14+01F0339S; 2020-07-30 23:32...
# 15830    2020-07-30 23:56:36+01F0339S; 2020-07-30 23:59...
# 15831    2020-07-30 23:32:54+01F0339S; 2020-07-30 23:34...
# 15832    2020-07-30 23:04:52+01F0339S; 2020-07-30 23:07...
# 15833    2020-07-30 23:00:19+01F0339S; 2020-07-30 23:03...
# 15834    2020-07-30 23:46:05+01F0339S; 2020-07-30 23:48...
# 15835    2020-07-30 23:20:52+01F0339S; 2020-07-30 23:23...
# 15836    2020-07-30 23:03:05+01F0339S; 2020-07-30 23:05...
# 15837    2020-07-30 23:11:19+01F0339S; 2020-07-30 23:13...
# 15838    2020-07-30 23:23:42+01F0339S; 2020-07-30 23:26...
# Name: 7, Length: 15839, dtype: object

# %%
# Calculate the latencies and time for each row and append it to the array to use for plotting.

latency = []
time_of_the_day = []

for i in range(len(example)):
    temp = re.split('[+]', example[i])
    t1 = temp[0]
    t2 = re.split('[;]', temp[4])[1]
    t1 = pd.to_datetime(t1)
    t2 = pd.to_datetime(t2)
    diff = pd.Timedelta(t2 - t1).total_seconds()
    latency.append(diff)
    time_of_the_day.append(t1)

# %%
# Check if the lengths of both arrays match to make sure the data is correct. Here, the index of each array represents the latency/time of its counterpart. For example, for index i, the latency is latency[i] and the time is time_of_the_day[i].

print('Length of Latency Array: '+str(len(latency)))
print('Length of Time Array: '+str(len(time_of_the_day)))
# Out:
# Length of Latency Array: 15839
# Length of Time Array: 15839

# %%
time_of_the_day[0]
# Out:
# Timestamp('2020-07-02 00:57:13')

# %%
date_df = pd.DataFrame({'TimeStamp':time_of_the_day})

# %%
date_df.head()
# Out:
#             TimeStamp
# 0 2020-07-02 00:57:13
# 1 2020-07-02 00:52:46
# 2 2020-07-02 00:49:49
# 3 2020-07-02 00:16:21
# 4 2020-07-02 00:08:18

# %%
# date_df['TimeStamp'] = pd.Series([val.time() for val in date_df['TimeStamp']])
time_only = pd.DatetimeIndex(date_df['TimeStamp']).time

# %%
time_only[0]
# Out:
# datetime.time(0, 57, 13)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(time_only, latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 July Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Since the above plot has a lot of noise with latency values greater than a certain threshold (~1500), any latency values greater than 1500 sohuld be removed. 

# Convert the lists into a dataframe to filter out rows which have latency values > 1500.
new_df = pd.DataFrame({'Time':time_only,'Latency':latency})

new_df.drop(new_df[(new_df['Latency']>1500)].index,inplace=True)

# %%
# Convert the new dataframe with latencies < 1500 into a list for plotting.

new_time = (new_df['Time'].to_list())
new_latency = (new_df['Latency'].to_list())

# %%
plt.figure(figsize=(15,10))
plt.scatter(new_time, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 July Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Convert time to time in hours.

time_in_hours = []
for i in range(len(new_time)):
    temp = new_time[i].hour + new_time[i].minute/60
    time_in_hours.append(temp)

# %%
plt.figure(figsize=(15,10))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 July Thursdays')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24)
plt.show()

# %%
# Plot a polynomial regression line to fit the scatter plot.

x = time_in_hours
y = new_latency
# np.ployfit(x, y, N) where x is the x values, y is the y values, and N is the Nth ploynomial regression.
z = np.polyfit(x, y, 30)
p = np.poly1d(z)
xp = np.linspace(0,24)

plt.figure(figsize=(15,7))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.plot(xp, p(xp), '-', marker = 'x', c = 'green')
plt.title('Latency vs. Time of the day for 2020 July Thursdays with latency limit at 1500s')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24)
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
