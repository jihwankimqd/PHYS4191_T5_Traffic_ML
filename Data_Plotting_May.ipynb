# %%
import pandas as pd
import numpy as np

# %%
March_05 = pd.read_csv('May_07_FullData.csv')
March_12 = pd.read_csv('May_14_FullData.csv')
March_19 = pd.read_csv('May_21_FullData.csv')
March_26 = pd.read_csv('May_28_FullData.csv')

# %%
March_05.head()
# Out:
#    Unnamed: 0   0                    1         2                    3  \
# 0           0  31  2020-05-07 00:19:17  03F4142S  2020-05-07 00:19:17
# 1           1  32  2020-05-07 00:30:29  03F1739N  2020-05-07 00:42:39
# 2           2  31  2020-05-07 00:19:09  01F0017S  2020-05-07 00:23:52
# 3           3  31  2020-05-07 00:20:31  01F0980S  2020-05-07 00:38:03
# 4           4  31  2020-05-07 00:05:52  01F0509S  2020-05-07 00:05:52
#
#           4     5  6                                                  7
# 0  03F4142S   7.9  Y                       2020-05-07 00:19:17+03F4142S
# 1  03F1739S   7.4  Y  2020-05-07 00:30:29+03F1739N; 2020-05-07 00:42...
# 2  01F0099S   9.4  Y  2020-05-07 00:19:09+01F0017S; 2020-05-07 00:19...
# 3  01F1292S  37.4  Y  2020-05-07 00:20:31+01F0980S; 2020-05-07 00:24...
# 4  01F0509S   3.4  Y                       2020-05-07 00:05:52+01F0509S

# %%
# Check column names and drop the first column ('Unnamed: 0').

March_05.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
March_05.drop(columns=['Unnamed: 0'],inplace=True)
March_12.drop(columns=['Unnamed: 0'],inplace=True)
March_19.drop(columns=['Unnamed: 0'],inplace=True)
March_26.drop(columns=['Unnamed: 0'],inplace=True)

# %%
March_05.head()
# Out:
#     0                    1         2                    3         4     5  6  \
# 0  31  2020-05-07 00:19:17  03F4142S  2020-05-07 00:19:17  03F4142S   7.9  Y
# 1  32  2020-05-07 00:30:29  03F1739N  2020-05-07 00:42:39  03F1739S   7.4  Y
# 2  31  2020-05-07 00:19:09  01F0017S  2020-05-07 00:23:52  01F0099S   9.4  Y
# 3  31  2020-05-07 00:20:31  01F0980S  2020-05-07 00:38:03  01F1292S  37.4  Y
# 4  31  2020-05-07 00:05:52  01F0509S  2020-05-07 00:05:52  01F0509S   3.4  Y
#
#                                                    7
# 0                       2020-05-07 00:19:17+03F4142S
# 1  2020-05-07 00:30:29+03F1739N; 2020-05-07 00:42...
# 2  2020-05-07 00:19:09+01F0017S; 2020-05-07 00:19...
# 3  2020-05-07 00:20:31+01F0980S; 2020-05-07 00:24...
# 4                       2020-05-07 00:05:52+01F0509S

# %%
# Only interested in data between 01F0339S and 01F0509S. Therefore, filter out irrelevant data.

March_05 = March_05[March_05["2"].str.contains("339S", na=False)]
March_05 = March_05[March_05["4"].str.contains("509S", na=False)]

March_12 = March_12[March_12["2"].str.contains("339S", na=False)]
March_12 = March_12[March_12["4"].str.contains("509S", na=False)]

March_19 = March_19[March_19["2"].str.contains("339S", na=False)]
March_19 = March_19[March_19["4"].str.contains("509S", na=False)]

March_26 = March_26[March_26["2"].str.contains("339S", na=False)]
March_26 = March_26[March_26["4"].str.contains("509S", na=False)]

# %%
March_05.head()
# Out:
#        0                    1         2                    3         4     5  \
# 2205  31  2020-05-07 00:50:59  01F0339S  2020-05-07 00:59:19  01F0509S  19.4
# 2315  32  2020-05-07 00:28:29  01F0339S  2020-05-07 00:38:14  01F0509S  19.4
# 3456  32  2020-05-07 00:38:36  01F0339S  2020-05-07 00:49:11  01F0509S  19.4
# 3505  31  2020-05-07 00:05:26  01F0339S  2020-05-07 00:16:39  01F0509S  19.4
# 4385  31  2020-05-07 00:39:50  01F0339S  2020-05-07 00:49:59  01F0509S  19.4
#
#       6                                                  7
# 2205  Y  2020-05-07 00:50:59+01F0339S; 2020-05-07 00:52...
# 2315  Y  2020-05-07 00:28:29+01F0339S; 2020-05-07 00:30...
# 3456  Y  2020-05-07 00:38:36+01F0339S; 2020-05-07 00:41...
# 3505  Y  2020-05-07 00:05:26+01F0339S; 2020-05-07 00:07...
# 4385  Y  2020-05-07 00:39:50+01F0339S; 2020-05-07 00:41...

# %%
March_12.head()
# Out:
#        0                    1         2                    3         4     5  \
# 637   31  2020-05-14 00:15:10  01F0339S  2020-05-14 00:25:39  01F0509S  19.4
# 1361   5  2020-05-14 00:24:06  01F0339S  2020-05-14 00:35:57  01F0509S  19.4
# 2035  42  2020-05-14 00:28:12  01F0339S  2020-05-14 00:43:45  01F0509S  19.4
# 2309  32  2020-05-14 00:08:29  01F0339S  2020-05-14 00:18:00  01F0509S  19.4
# 4016  31  2020-05-14 00:02:23  01F0339S  2020-05-14 00:11:36  01F0509S  19.4
#
#       6                                                  7
# 637   Y  2020-05-14 00:15:10+01F0339S; 2020-05-14 00:17...
# 1361  Y  2020-05-14 00:24:06+01F0339S; 2020-05-14 00:27...
# 2035  Y  2020-05-14 00:28:12+01F0339S; 2020-05-14 00:31...
# 2309  Y  2020-05-14 00:08:29+01F0339S; 2020-05-14 00:10...
# 4016  Y  2020-05-14 00:02:23+01F0339S; 2020-05-14 00:04...

# %%
March_19.head()
# Out:
#        0                    1         2                    3         4     5  \
# 910   31  2020-05-21 00:07:34  01F0339S  2020-05-21 00:17:11  01F0509S  19.4
# 996   42  2020-05-21 00:33:53  01F0339S  2020-05-21 00:45:47  01F0509S  19.4
# 1773  31  2020-05-21 00:44:15  01F0339S  2020-05-21 00:54:01  01F0509S  19.4
# 1867  31  2020-05-21 00:15:40  01F0339S  2020-05-21 00:27:51  01F0509S  19.4
# 2303  32  2020-05-21 00:18:31  01F0339S  2020-05-21 00:28:27  01F0509S  19.4
#
#       6                                                  7
# 910   Y  2020-05-21 00:07:34+01F0339S; 2020-05-21 00:09...
# 996   Y  2020-05-21 00:33:53+01F0339S; 2020-05-21 00:36...
# 1773  Y  2020-05-21 00:44:15+01F0339S; 2020-05-21 00:46...
# 1867  Y  2020-05-21 00:15:40+01F0339S; 2020-05-21 00:18...
# 2303  Y  2020-05-21 00:18:31+01F0339S; 2020-05-21 00:20...

# %%
March_26.head()
# Out:
#        0                    1         2                    3         4     5  \
# 316   31  2020-05-28 00:22:03  01F0339S  2020-05-28 00:30:41  01F0509S  19.4
# 2156  32  2020-05-28 00:14:30  01F0339S  2020-05-28 00:23:33  01F0509S  19.4
# 3739  31  2020-05-28 00:52:19  01F0339S  2020-05-28 01:03:41  01F0509S  19.4
# 3951   5  2020-05-28 00:56:28  01F0339S  2020-05-28 01:09:36  01F0509S  19.4
# 4402   5  2020-05-28 00:57:51  01F0339S  2020-05-28 01:11:05  01F0509S  19.4
#
#       6                                                  7
# 316   Y  2020-05-28 00:22:03+01F0339S; 2020-05-28 00:23...
# 2156  Y  2020-05-28 00:14:30+01F0339S; 2020-05-28 00:16...
# 3739  Y  2020-05-28 00:52:19+01F0339S; 2020-05-28 00:54...
# 3951  Y  2020-05-28 00:56:28+01F0339S; 2020-05-28 00:59...
# 4402  Y  2020-05-28 00:57:51+01F0339S; 2020-05-28 01:00...

# %%
total_data_rows = March_05.shape[0]+March_12.shape[0]+March_19.shape[0]+March_26.shape[0]
print('Total Rows of Data: '+str(total_data_rows))
# Out:
# Total Rows of Data: 12568

# %%
# Combine into one dataframe

df = pd.concat([March_05,March_12,March_19,March_26], ignore_index=True)
df.shape
# Out:
# (12568, 8)

# %%
# Save the cleaned raw data file as a csv file.

df.to_csv('Cleaned_Raw_Data.csv')

# %%
import re

example = df['7']
example
# Out:
# 0        2020-05-07 00:50:59+01F0339S; 2020-05-07 00:52...
# 1        2020-05-07 00:28:29+01F0339S; 2020-05-07 00:30...
# 2        2020-05-07 00:38:36+01F0339S; 2020-05-07 00:41...
# 3        2020-05-07 00:05:26+01F0339S; 2020-05-07 00:07...
# 4        2020-05-07 00:39:50+01F0339S; 2020-05-07 00:41...
# 5        2020-05-07 00:51:32+01F0339S; 2020-05-07 00:54...
# 6        2020-05-07 00:21:16+01F0339S; 2020-05-07 00:23...
# 7        2020-05-07 00:12:45+01F0339S; 2020-05-07 00:14...
# 8        2020-05-07 00:20:38+01F0339S; 2020-05-07 00:23...
# 9        2020-05-07 00:34:40+01F0339S; 2020-05-07 00:37...
# 10       2020-05-07 00:18:15+01F0339S; 2020-05-07 00:20...
# 11       2020-05-07 00:10:47+01F0339S; 2020-05-07 00:13...
# 12       2020-05-07 00:48:05+01F0339S; 2020-05-07 00:50...
# 13       2020-05-07 00:12:41+01F0339S; 2020-05-07 00:14...
# 14       2020-05-07 00:49:59+01F0339S; 2020-05-07 00:51...
# 15       2020-05-07 00:25:17+01F0339S; 2020-05-07 00:27...
# 16       2020-05-07 00:44:06+01F0339S; 2020-05-07 00:46...
# 17       2020-05-07 00:21:20+01F0339S; 2020-05-07 00:23...
# 18       2020-05-07 00:00:51+01F0339S; 2020-05-07 00:02...
# 19       2020-05-07 00:22:24+01F0339S; 2020-05-07 00:24...
# 20       2020-05-07 00:09:35+01F0339S; 2020-05-07 00:11...
# 21       2020-05-07 00:34:37+01F0339S; 2020-05-07 00:36...
# 22       2020-05-07 00:03:39+01F0339S; 2020-05-07 00:05...
# 23       2020-05-07 00:19:52+01F0339S; 2020-05-07 00:22...
# 24       2020-05-07 00:41:44+01F0339S; 2020-05-07 00:44...
# 25       2020-05-07 00:30:16+01F0339S; 2020-05-07 00:33...
# 26       2020-05-07 00:29:36+01F0339S; 2020-05-07 00:31...
# 27       2020-05-07 00:11:28+01F0339S; 2020-05-07 00:13...
# 28       2020-05-07 00:51:57+01F0339S; 2020-05-07 00:54...
# 29       2020-05-07 00:26:32+01F0339S; 2020-05-07 00:28...
#                                ...
# 12538    2020-05-28 23:03:27+01F0339S; 2020-05-28 23:05...
# 12539    2020-05-28 23:41:53+01F0339S; 2020-05-28 23:43...
# 12540    2020-05-28 23:36:51+01F0339S; 2020-05-28 23:39...
# 12541    2020-05-28 23:38:49+01F0339S; 2020-05-28 23:41...
# 12542    2020-05-28 23:06:55+01F0339S; 2020-05-28 23:09...
# 12543    2020-05-28 23:23:25+01F0339S; 2020-05-28 23:25...
# 12544    2020-05-28 23:09:12+01F0339S; 2020-05-28 23:11...
# 12545    2020-05-28 23:07:45+01F0339S; 2020-05-28 23:09...
# 12546    2020-05-28 23:18:53+01F0339S; 2020-05-28 23:21...
# 12547    2020-05-28 23:00:58+01F0339S; 2020-05-28 23:03...
# 12548    2020-05-28 23:15:33+01F0339S; 2020-05-28 23:17...
# 12549    2020-05-28 23:59:27+01F0339S; 2020-05-29 00:01...
# 12550    2020-05-28 23:43:48+01F0339S; 2020-05-28 23:46...
# 12551    2020-05-28 23:19:00+01F0339S; 2020-05-28 23:21...
# 12552    2020-05-28 23:22:02+01F0339S; 2020-05-28 23:24...
# 12553    2020-05-28 23:42:44+01F0339S; 2020-05-28 23:45...
# 12554    2020-05-28 23:47:48+01F0339S; 2020-05-28 23:50...
# 12555    2020-05-28 23:30:03+01F0339S; 2020-05-28 23:32...
# 12556    2020-05-28 23:54:06+01F0339S; 2020-05-28 23:56...
# 12557    2020-05-28 23:56:53+01F0339S; 2020-05-28 23:59...
# 12558    2020-05-28 23:19:05+01F0339S; 2020-05-28 23:20...
# 12559    2020-05-28 23:00:17+01F0339S; 2020-05-28 23:02...
# 12560    2020-05-28 23:09:47+01F0339S; 2020-05-28 23:12...
# 12561    2020-05-28 23:01:47+01F0339S; 2020-05-28 23:04...
# 12562    2020-05-28 23:25:11+01F0339S; 2020-05-28 23:28...
# 12563    2020-05-28 23:46:09+01F0339S; 2020-05-28 23:48...
# 12564    2020-05-28 23:19:21+01F0339S; 2020-05-28 23:21...
# 12565    2020-05-28 23:05:47+01F0339S; 2020-05-28 23:07...
# 12566    2020-05-28 23:30:46+01F0339S; 2020-05-28 23:33...
# 12567    2020-05-28 23:38:40+01F0339S; 2020-05-28 23:40...
# Name: 7, Length: 12568, dtype: object

# %%
# Calculate the latencies and time for each row and append it to the array to use for plotting.

latency = []
time_of_the_day = []

for i in range(len(example)):
    temp = re.split('[+]', example[i])
    t1 = temp[0]
    t2 = re.split('[;]', temp[4])[1]
    t1 = pd.to_datetime(t1)
    t2 = pd.to_datetime(t2)
    diff = pd.Timedelta(t2 - t1).total_seconds()
    latency.append(diff)
    time_of_the_day.append(t1)

# %%
# Check if the lengths of both arrays match to make sure the data is correct. Here, the index of each array represents the latency/time of its counterpart. For example, for index i, the latency is latency[i] and the time is time_of_the_day[i].

print('Length of Latency Array: '+str(len(latency)))
print('Length of Time Array: '+str(len(time_of_the_day)))
# Out:
# Length of Latency Array: 12568
# Length of Time Array: 12568

# %%
time_of_the_day[0]
# Out:
# Timestamp('2020-05-07 00:50:59')

# %%
date_df = pd.DataFrame({'TimeStamp':time_of_the_day})

# %%
date_df.head()
# Out:
#             TimeStamp
# 0 2020-05-07 00:50:59
# 1 2020-05-07 00:28:29
# 2 2020-05-07 00:38:36
# 3 2020-05-07 00:05:26
# 4 2020-05-07 00:39:50

# %%
# date_df['TimeStamp'] = pd.Series([val.time() for val in date_df['TimeStamp']])
time_only = pd.DatetimeIndex(date_df['TimeStamp']).time

# %%
time_only[0]
# Out:
# datetime.time(0, 50, 59)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(time_only, latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 May Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Since the above plot has a lot of noise with latency values greater than a certain threshold (~1500), any latency values greater than 1500 sohuld be removed. 

# Convert the lists into a dataframe to filter out rows which have latency values > 1500.
new_df = pd.DataFrame({'Time':time_only,'Latency':latency})

new_df.drop(new_df[(new_df['Latency']>1500)].index,inplace=True)

# %%
# Convert the new dataframe with latencies < 1500 into a list for plotting.

new_time = (new_df['Time'].to_list())
new_latency = (new_df['Latency'].to_list())

# %%
plt.figure(figsize=(15,10))
plt.scatter(new_time, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 May Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Convert time to time in hours.

time_in_hours = []
for i in range(len(new_time)):
    temp = new_time[i].hour + new_time[i].minute/60
    time_in_hours.append(temp)

# %%
plt.figure(figsize=(15,10))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 May Thursdays')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24)
plt.show()

# %%
# Plot a polynomial regression line to fit the scatter plot.

x = time_in_hours
y = new_latency
# np.ployfit(x, y, N) where x is the x values, y is the y values, and N is the Nth ploynomial regression.
z = np.polyfit(x, y, 30)
p = np.poly1d(z)
xp = np.linspace(0,24)

plt.figure(figsize=(15,7))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.plot(xp, p(xp), '-', marker = 'x', c = 'green')
plt.title('Latency vs. Time of the day for 2020 May Thursdays with latency limit at 1500s')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24) 
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
