# %%
import pandas as pd
import numpy as np

# %%
March_05 = pd.read_csv('Aug_06_FullData.csv')
March_12 = pd.read_csv('Aug_13_FullData.csv')
March_19 = pd.read_csv('Aug_20_FullData.csv')
March_26 = pd.read_csv('Aug_27_FullData.csv')

# %%
March_05.head()
# Out:
#    Unnamed: 0   0                    1         2                    3  \
# 0           0  42  2020-08-06 00:45:22  03F1860S  2020-08-06 01:03:07
# 1           1  31  2020-08-06 00:25:45  03F1161N  2020-08-06 02:06:29
# 2           2  31  2020-08-06 00:00:08  03F0158S  2020-08-06 00:31:15
# 3           3  32  2020-08-06 00:26:29  01F3590S  2020-08-06 00:30:01
# 4           4  32  2020-08-06 00:05:45  03F0394S  2020-08-06 00:23:55
#
#           4     5  6                                                  7
# 0  03F2129S  31.2  Y  2020-08-06 00:45:22+03F1860S; 2020-08-06 00:51...
# 1  01F0467N  76.2  Y  2020-08-06 00:25:45+03F1161N; 2020-08-06 00:27...
# 2  05F0439S  47.9  Y  2020-08-06 00:00:08+03F0158S; 2020-08-06 00:00...
# 3  01F3640S  11.2  Y  2020-08-06 00:26:29+01F3590S; 2020-08-06 00:30...
# 4  01F0557S  34.8  Y  2020-08-06 00:05:45+03F0394S; 2020-08-06 00:09...

# %%
# Check column names and drop the first column ('Unnamed: 0').

March_05.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
March_05.drop(columns=['Unnamed: 0'],inplace=True)
March_12.drop(columns=['Unnamed: 0'],inplace=True)
March_19.drop(columns=['Unnamed: 0'],inplace=True)
March_26.drop(columns=['Unnamed: 0'],inplace=True)

# %%
March_05.head()
# Out:
#     0                    1         2                    3         4     5  6  \
# 0  42  2020-08-06 00:45:22  03F1860S  2020-08-06 01:03:07  03F2129S  31.2  Y
# 1  31  2020-08-06 00:25:45  03F1161N  2020-08-06 02:06:29  01F0467N  76.2  Y
# 2  31  2020-08-06 00:00:08  03F0158S  2020-08-06 00:31:15  05F0439S  47.9  Y
# 3  32  2020-08-06 00:26:29  01F3590S  2020-08-06 00:30:01  01F3640S  11.2  Y
# 4  32  2020-08-06 00:05:45  03F0394S  2020-08-06 00:23:55  01F0557S  34.8  Y
#
#                                                    7
# 0  2020-08-06 00:45:22+03F1860S; 2020-08-06 00:51...
# 1  2020-08-06 00:25:45+03F1161N; 2020-08-06 00:27...
# 2  2020-08-06 00:00:08+03F0158S; 2020-08-06 00:00...
# 3  2020-08-06 00:26:29+01F3590S; 2020-08-06 00:30...
# 4  2020-08-06 00:05:45+03F0394S; 2020-08-06 00:09...

# %%
# Only interested in data between 01F0339S and 01F0509S. Therefore, filter out irrelevant data.

March_05 = March_05[March_05["2"].str.contains("339S", na=False)]
March_05 = March_05[March_05["4"].str.contains("509S", na=False)]

March_12 = March_12[March_12["2"].str.contains("339S", na=False)]
March_12 = March_12[March_12["4"].str.contains("509S", na=False)]

March_19 = March_19[March_19["2"].str.contains("339S", na=False)]
March_19 = March_19[March_19["4"].str.contains("509S", na=False)]

March_26 = March_26[March_26["2"].str.contains("339S", na=False)]
March_26 = March_26[March_26["4"].str.contains("509S", na=False)]

# %%
March_05.head()
# Out:
#        0                    1         2                    3         4     5  \
# 295   32  2020-08-06 00:38:56  01F0339S  2020-08-06 00:49:48  01F0509S  19.4
# 1912  31  2020-08-06 00:13:54  01F0339S  2020-08-06 00:22:40  01F0509S  19.4
# 2053  31  2020-08-06 00:08:59  01F0339S  2020-08-06 00:18:36  01F0509S  19.4
# 3016  32  2020-08-06 00:25:19  01F0339S  2020-08-06 00:33:48  01F0509S  19.4
# 3748  31  2020-08-06 00:03:05  01F0339S  2020-08-06 00:12:10  01F0509S  19.4
#
#       6                                                  7
# 295   Y  2020-08-06 00:38:56+01F0339S; 2020-08-06 00:41...
# 1912  Y  2020-08-06 00:13:54+01F0339S; 2020-08-06 00:15...
# 2053  Y  2020-08-06 00:08:59+01F0339S; 2020-08-06 00:11...
# 3016  Y  2020-08-06 00:25:19+01F0339S; 2020-08-06 00:27...
# 3748  Y  2020-08-06 00:03:05+01F0339S; 2020-08-06 00:05...

# %%
March_12.head()
# Out:
#        0                    1         2                    3         4     5  \
# 1068  32  2020-08-13 00:19:40  01F0339S  2020-08-13 00:30:22  01F0509S  19.4
# 1281  32  2020-08-13 00:30:36  01F0339S  2020-08-13 00:59:38  01F0509S  19.4
# 1297  31  2020-08-13 00:16:24  01F0339S  2020-08-13 00:26:34  01F0509S  19.4
# 1629  31  2020-08-13 00:23:13  01F0339S  2020-08-13 00:32:07  01F0509S  19.4
# 5371   5  2020-08-13 00:32:50  01F0339S  2020-08-13 00:45:15  01F0509S  19.4
#
#       6                                                  7
# 1068  Y  2020-08-13 00:19:40+01F0339S; 2020-08-13 00:22...
# 1281  Y  2020-08-13 00:30:36+01F0339S; 2020-08-13 00:32...
# 1297  Y  2020-08-13 00:16:24+01F0339S; 2020-08-13 00:18...
# 1629  Y  2020-08-13 00:23:13+01F0339S; 2020-08-13 00:25...
# 5371  Y  2020-08-13 00:32:50+01F0339S; 2020-08-13 00:35...

# %%
March_19.head()
# Out:
#        0                    1         2                    3         4     5  \
# 180   31  2020-08-20 00:06:26  01F0339S  2020-08-20 00:29:58  01F0509S  19.4
# 778   32  2020-08-20 00:11:29  01F0339S  2020-08-20 00:35:47  01F0509S  19.4
# 1271  32  2020-08-20 00:06:47  01F0339S  2020-08-20 00:31:02  01F0509S  19.4
# 1794  31  2020-08-20 00:17:53  01F0339S  2020-08-20 00:44:10  01F0509S  19.4
# 2280  42  2020-08-20 00:08:06  01F0339S  2020-08-20 00:29:04  01F0509S  19.4
#
#       6                                                  7
# 180   Y  2020-08-20 00:06:26+01F0339S; 2020-08-20 00:08...
# 778   Y  2020-08-20 00:11:29+01F0339S; 2020-08-20 00:14...
# 1271  Y  2020-08-20 00:06:47+01F0339S; 2020-08-20 00:08...
# 1794  Y  2020-08-20 00:17:53+01F0339S; 2020-08-20 00:20...
# 2280  Y  2020-08-20 00:08:06+01F0339S; 2020-08-20 00:10...

# %%
March_26.head()
# Out:
#        0                    1         2                    3         4     5  \
# 377   31  2020-08-27 00:25:31  01F0339S  2020-08-27 00:36:23  01F0509S  19.4
# 954   31  2020-08-27 00:36:17  01F0339S  2020-08-27 00:47:41  01F0509S  19.4
# 1821  32  2020-08-27 00:14:06  01F0339S  2020-08-27 00:26:52  01F0509S  19.4
# 2578  31  2020-08-27 00:34:53  01F0339S  2020-08-27 00:43:55  01F0509S  19.4
# 2728  31  2020-08-27 00:30:46  01F0339S  2020-08-27 00:43:24  01F0509S  19.4
#
#       6                                                  7
# 377   Y  2020-08-27 00:25:31+01F0339S; 2020-08-27 00:28...
# 954   Y  2020-08-27 00:36:17+01F0339S; 2020-08-27 00:38...
# 1821  Y  2020-08-27 00:14:06+01F0339S; 2020-08-27 00:16...
# 2578  Y  2020-08-27 00:34:53+01F0339S; 2020-08-27 00:36...
# 2728  Y  2020-08-27 00:30:46+01F0339S; 2020-08-27 00:33...

# %%
total_data_rows = March_05.shape[0]+March_12.shape[0]+March_19.shape[0]+March_26.shape[0]
print('Total Rows of Data: '+str(total_data_rows))
# Out:
# Total Rows of Data: 13044

# %%
# Combine into one dataframe

df = pd.concat([March_05,March_12,March_19,March_26], ignore_index=True)
df.shape
# Out:
# (13044, 8)

# %%
# Save the cleaned raw data file as a csv file.

df.to_csv('Cleaned_Raw_Data.csv')

# %%
import re

example = df['7']
example
# Out:
# 0        2020-08-06 00:38:56+01F0339S; 2020-08-06 00:41...
# 1        2020-08-06 00:13:54+01F0339S; 2020-08-06 00:15...
# 2        2020-08-06 00:08:59+01F0339S; 2020-08-06 00:11...
# 3        2020-08-06 00:25:19+01F0339S; 2020-08-06 00:27...
# 4        2020-08-06 00:03:05+01F0339S; 2020-08-06 00:05...
# 5        2020-08-06 00:10:23+01F0339S; 2020-08-06 00:12...
# 6        2020-08-06 00:42:52+01F0339S; 2020-08-06 00:45...
# 7        2020-08-06 00:17:29+01F0339S; 2020-08-06 00:18...
# 8        2020-08-06 00:25:40+01F0339S; 2020-08-06 00:27...
# 9        2020-08-06 00:53:08+01F0339S; 2020-08-06 00:55...
# 10       2020-08-06 00:42:07+01F0339S; 2020-08-06 00:44...
# 11       2020-08-06 00:19:11+01F0339S; 2020-08-06 00:20...
# 12       2020-08-06 00:13:13+01F0339S; 2020-08-06 00:15...
# 13       2020-08-06 00:15:44+01F0339S; 2020-08-06 00:18...
# 14       2020-08-06 00:26:33+01F0339S; 2020-08-06 00:28...
# 15       2020-08-06 00:59:38+01F0339S; 2020-08-06 01:01...
# 16       2020-08-06 00:08:56+01F0339S; 2020-08-06 00:11...
# 17       2020-08-06 00:26:24+01F0339S; 2020-08-06 00:28...
# 18       2020-08-06 00:51:55+01F0339S; 2020-08-06 00:53...
# 19       2020-08-06 00:50:59+01F0339S; 2020-08-06 00:53...
# 20       2020-08-06 00:02:22+01F0339S; 2020-08-06 00:04...
# 21       2020-08-06 00:15:59+01F0339S; 2020-08-06 00:18...
# 22       2020-08-06 00:29:29+01F0339S; 2020-08-06 00:31...
# 23       2020-08-06 00:38:13+01F0339S; 2020-08-06 00:40...
# 24       2020-08-06 00:00:05+01F0339S; 2020-08-06 00:02...
# 25       2020-08-06 00:56:11+01F0339S; 2020-08-06 00:57...
# 26       2020-08-06 00:56:44+01F0339S; 2020-08-06 00:58...
# 27       2020-08-06 00:39:27+01F0339S; 2020-08-06 00:41...
# 28       2020-08-06 00:36:01+01F0339S; 2020-08-06 00:38...
# 29       2020-08-06 00:11:05+01F0339S; 2020-08-06 00:13...
#                                ...
# 13014    2020-08-27 23:14:29+01F0339S; 2020-08-27 23:17...
# 13015    2020-08-27 23:55:15+01F0339S; 2020-08-27 23:57...
# 13016    2020-08-27 23:45:53+01F0339S; 2020-08-27 23:48...
# 13017    2020-08-27 23:49:16+01F0339S; 2020-08-27 23:51...
# 13018    2020-08-27 23:08:30+01F0339S; 2020-08-27 23:10...
# 13019    2020-08-27 23:19:04+01F0339S; 2020-08-27 23:21...
# 13020    2020-08-27 23:27:23+01F0339S; 2020-08-27 23:29...
# 13021    2020-08-27 23:20:45+01F0339S; 2020-08-27 23:23...
# 13022    2020-08-27 23:55:46+01F0339S; 2020-08-27 23:58...
# 13023    2020-08-27 23:40:47+01F0339S; 2020-08-27 23:42...
# 13024    2020-08-27 23:56:35+01F0339S; 2020-08-27 23:58...
# 13025    2020-08-27 23:26:26+01F0339S; 2020-08-27 23:28...
# 13026    2020-08-27 23:58:46+01F0339S; 2020-08-28 00:00...
# 13027    2020-08-27 23:56:05+01F0339S; 2020-08-27 23:58...
# 13028    2020-08-27 23:59:22+01F0339S; 2020-08-28 00:01...
# 13029    2020-08-27 23:53:07+01F0339S; 2020-08-27 23:56...
# 13030    2020-08-27 23:45:37+01F0339S; 2020-08-27 23:48...
# 13031    2020-08-27 23:25:43+01F0339S; 2020-08-27 23:27...
# 13032    2020-08-27 23:45:41+01F0339S; 2020-08-27 23:48...
# 13033    2020-08-27 23:27:14+01F0339S; 2020-08-27 23:30...
# 13034    2020-08-27 23:08:01+01F0339S; 2020-08-27 23:10...
# 13035    2020-08-27 23:47:18+01F0339S; 2020-08-27 23:49...
# 13036    2020-08-27 23:17:56+01F0339S; 2020-08-27 23:20...
# 13037    2020-08-27 23:00:17+01F0339S; 2020-08-27 23:02...
# 13038    2020-08-27 23:45:09+01F0339S; 2020-08-27 23:47...
# 13039    2020-08-27 23:45:19+01F0339S; 2020-08-27 23:47...
# 13040    2020-08-27 23:45:25+01F0339S; 2020-08-27 23:47...
# 13041    2020-08-27 23:22:07+01F0339S; 2020-08-27 23:24...
# 13042    2020-08-27 23:26:57+01F0339S; 2020-08-27 23:29...
# 13043    2020-08-27 23:03:10+01F0339S; 2020-08-27 23:05...
# Name: 7, Length: 13044, dtype: object

# %%
# Calculate the latencies and time for each row and append it to the array to use for plotting.

latency = []
time_of_the_day = []

for i in range(len(example)):
    temp = re.split('[+]', example[i])
    t1 = temp[0]
    t2 = re.split('[;]', temp[4])[1]
    t1 = pd.to_datetime(t1)
    t2 = pd.to_datetime(t2)
    diff = pd.Timedelta(t2 - t1).total_seconds()
    latency.append(diff)
    time_of_the_day.append(t1)

# %%
# Check if the lengths of both arrays match to make sure the data is correct. Here, the index of each array represents the latency/time of its counterpart. For example, for index i, the latency is latency[i] and the time is time_of_the_day[i].

print('Length of Latency Array: '+str(len(latency)))
print('Length of Time Array: '+str(len(time_of_the_day)))
# Out:
# Length of Latency Array: 13044
# Length of Time Array: 13044

# %%
time_of_the_day[0]
# Out:
# Timestamp('2020-08-06 00:38:56')

# %%
date_df = pd.DataFrame({'TimeStamp':time_of_the_day})

# %%
date_df.head()
# Out:
#             TimeStamp
# 0 2020-08-06 00:38:56
# 1 2020-08-06 00:13:54
# 2 2020-08-06 00:08:59
# 3 2020-08-06 00:25:19
# 4 2020-08-06 00:03:05

# %%
# date_df['TimeStamp'] = pd.Series([val.time() for val in date_df['TimeStamp']])
time_only = pd.DatetimeIndex(date_df['TimeStamp']).time

# %%
time_only[0]
# Out:
# datetime.time(0, 38, 56)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(time_only, latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 Aug Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Since the above plot has a lot of noise with latency values greater than a certain threshold (~1500), any latency values greater than 1500 sohuld be removed. 

# Convert the lists into a dataframe to filter out rows which have latency values > 1500.
new_df = pd.DataFrame({'Time':time_only,'Latency':latency})

new_df.drop(new_df[(new_df['Latency']>1500)].index,inplace=True)

# %%
# Convert the new dataframe with latencies < 1500 into a list for plotting.

new_time = (new_df['Time'].to_list())
new_latency = (new_df['Latency'].to_list())

# %%
plt.figure(figsize=(15,10))
plt.scatter(new_time, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 Aug Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Convert time to time in hours.

time_in_hours = []
for i in range(len(new_time)):
    temp = new_time[i].hour + new_time[i].minute/60
    time_in_hours.append(temp)

# %%
plt.figure(figsize=(15,10))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 Aug Thursdays')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24)
plt.show()

# %%
# Plot a polynomial regression line to fit the scatter plot.

x = time_in_hours
y = new_latency
# np.ployfit(x, y, N) where x is the x values, y is the y values, and N is the Nth ploynomial regression.
z = np.polyfit(x, y, 30)
p = np.poly1d(z)
xp = np.linspace(0,24)

plt.figure(figsize=(15,7))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.plot(xp, p(xp), '-', marker = 'x', c = 'green')
plt.title('Latency vs. Time of the day for 2020 Aug Thursdays with latency limit at 1500s')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24) 
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
