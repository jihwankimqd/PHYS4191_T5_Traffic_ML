# %%
import pandas as pd
import numpy as np

# %%
March_05 = pd.read_csv('Sep_03_FullData.csv')
March_12 = pd.read_csv('Sep_10_FullData.csv')
March_19 = pd.read_csv('Sep_17_FullData.csv')
March_26 = pd.read_csv('Sep_24_FullData.csv')

# %%
March_05.head()
# Out:
#    Unnamed: 0   0                    1         2                    3  \
# 0           0  31  2020-09-03 00:06:15  03F2100S  2020-09-03 00:28:40
# 1           1  31  2020-09-03 00:48:21  01F3640N  2020-09-03 00:48:21
# 2           2  41  2020-09-03 00:05:39  01F0005S  2020-09-03 00:05:39
# 3           3  42  2020-09-03 00:00:51  03F0559S  2020-09-03 00:00:51
# 4           4  32  2020-09-03 00:38:51  01F0339S  2020-09-03 00:41:53
#
#           4     5  6                                                  7
# 0  03F2535S  51.3  Y  2020-09-03 00:06:15+03F2100S; 2020-09-03 00:08...
# 1  01F3640N   5.0  Y                       2020-09-03 00:48:21+01F3640N
# 2  01F0005S   1.1  Y                       2020-09-03 00:05:39+01F0005S
# 3  03F0559S   8.3  Y                       2020-09-03 00:00:51+03F0559S
# 4  01F0376S   8.4  Y  2020-09-03 00:38:51+01F0339S; 2020-09-03 00:41...

# %%
# Check column names and drop the first column ('Unnamed: 0').

March_05.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
March_05.drop(columns=['Unnamed: 0'],inplace=True)
March_12.drop(columns=['Unnamed: 0'],inplace=True)
March_19.drop(columns=['Unnamed: 0'],inplace=True)
March_26.drop(columns=['Unnamed: 0'],inplace=True)

# %%
March_05.head()
# Out:
#     0                    1         2                    3         4     5  6  \
# 0  31  2020-09-03 00:06:15  03F2100S  2020-09-03 00:28:40  03F2535S  51.3  Y
# 1  31  2020-09-03 00:48:21  01F3640N  2020-09-03 00:48:21  01F3640N   5.0  Y
# 2  41  2020-09-03 00:05:39  01F0005S  2020-09-03 00:05:39  01F0005S   1.1  Y
# 3  42  2020-09-03 00:00:51  03F0559S  2020-09-03 00:00:51  03F0559S   8.3  Y
# 4  32  2020-09-03 00:38:51  01F0339S  2020-09-03 00:41:53  01F0376S   8.4  Y
#
#                                                    7
# 0  2020-09-03 00:06:15+03F2100S; 2020-09-03 00:08...
# 1                       2020-09-03 00:48:21+01F3640N
# 2                       2020-09-03 00:05:39+01F0005S
# 3                       2020-09-03 00:00:51+03F0559S
# 4  2020-09-03 00:38:51+01F0339S; 2020-09-03 00:41...

# %%
# Only interested in data between 01F0339S and 01F0509S. Therefore, filter out irrelevant data.

March_05 = March_05[March_05["2"].str.contains("339S", na=False)]
March_05 = March_05[March_05["4"].str.contains("509S", na=False)]

March_12 = March_12[March_12["2"].str.contains("339S", na=False)]
March_12 = March_12[March_12["4"].str.contains("509S", na=False)]

March_19 = March_19[March_19["2"].str.contains("339S", na=False)]
March_19 = March_19[March_19["4"].str.contains("509S", na=False)]

March_26 = March_26[March_26["2"].str.contains("339S", na=False)]
March_26 = March_26[March_26["4"].str.contains("509S", na=False)]

# %%
March_05.head()
# Out:
#        0                    1         2                    3         4     5  \
# 1021  42  2020-09-03 00:45:24  01F0339S  2020-09-03 00:55:58  01F0509S  19.4
# 1911  31  2020-09-03 00:00:16  01F0339S  2020-09-03 00:10:49  01F0509S  19.4
# 2782  32  2020-09-03 00:00:37  01F0339S  2020-09-03 00:11:24  01F0509S  19.4
# 3816  31  2020-09-03 00:36:25  01F0339S  2020-09-03 00:47:12  01F0509S  19.4
# 4533   5  2020-09-03 00:45:28  01F0339S  2020-09-03 00:57:47  01F0509S  19.4
#
#       6                                                  7
# 1021  Y  2020-09-03 00:45:24+01F0339S; 2020-09-03 00:47...
# 1911  Y  2020-09-03 00:00:16+01F0339S; 2020-09-03 00:02...
# 2782  Y  2020-09-03 00:00:37+01F0339S; 2020-09-03 00:03...
# 3816  Y  2020-09-03 00:36:25+01F0339S; 2020-09-03 00:38...
# 4533  Y  2020-09-03 00:45:28+01F0339S; 2020-09-03 00:48...

# %%
March_12.head()
# Out:
#        0                    1         2                    3         4     5  \
# 499   42  2020-09-10 00:29:04  01F0339S  2020-09-10 00:41:53  01F0509S  19.4
# 656   31  2020-09-10 00:13:19  01F0339S  2020-09-10 00:23:48  01F0509S  19.4
# 2080  31  2020-09-10 00:50:30  01F0339S  2020-09-10 00:59:26  01F0509S  19.4
# 2290  31  2020-09-10 00:40:09  01F0339S  2020-09-10 00:49:45  01F0509S  19.4
# 2544  32  2020-09-10 00:29:53  01F0339S  2020-09-10 00:40:25  01F0509S  19.4
#
#       6                                                  7
# 499   Y  2020-09-10 00:29:04+01F0339S; 2020-09-10 00:31...
# 656   Y  2020-09-10 00:13:19+01F0339S; 2020-09-10 00:15...
# 2080  Y  2020-09-10 00:50:30+01F0339S; 2020-09-10 00:52...
# 2290  Y  2020-09-10 00:40:09+01F0339S; 2020-09-10 00:42...
# 2544  Y  2020-09-10 00:29:53+01F0339S; 2020-09-10 00:32...

# %%
March_19.head()
# Out:
#        0                    1         2                    3         4     5  \
# 576   31  2020-09-17 00:45:39  01F0339S  2020-09-17 00:56:32  01F0509S  19.4
# 592   31  2020-09-17 00:17:05  01F0339S  2020-09-17 00:27:22  01F0509S  19.4
# 816   31  2020-09-17 00:41:55  01F0339S  2020-09-17 00:51:41  01F0509S  19.4
# 1279  31  2020-09-17 00:48:23  01F0339S  2020-09-17 00:58:37  01F0509S  19.4
# 1859  31  2020-09-17 00:38:13  01F0339S  2020-09-17 00:48:51  01F0509S  19.4
#
#       6                                                  7
# 576   Y  2020-09-17 00:45:39+01F0339S; 2020-09-17 00:48...
# 592   Y  2020-09-17 00:17:05+01F0339S; 2020-09-17 00:19...
# 816   Y  2020-09-17 00:41:55+01F0339S; 2020-09-17 00:44...
# 1279  Y  2020-09-17 00:48:23+01F0339S; 2020-09-17 00:50...
# 1859  Y  2020-09-17 00:38:13+01F0339S; 2020-09-17 00:40...

# %%
March_26.head()
# Out:
#        0                    1         2                    3         4     5  \
# 1105  42  2020-09-24 00:28:47  01F0339S  2020-09-24 00:39:19  01F0509S  19.4
# 2154  42  2020-09-24 00:11:32  01F0339S  2020-09-24 00:24:11  01F0509S  19.4
# 2591  32  2020-09-24 00:17:43  01F0339S  2020-09-24 00:28:57  01F0509S  19.4
# 4171   5  2020-09-24 00:20:39  01F0339S  2020-09-24 00:51:29  01F0509S  19.4
# 4281  31  2020-09-24 00:12:04  01F0339S  2020-09-24 00:22:35  01F0509S  19.4
#
#       6                                                  7
# 1105  Y  2020-09-24 00:28:47+01F0339S; 2020-09-24 00:31...
# 2154  Y  2020-09-24 00:11:32+01F0339S; 2020-09-24 00:14...
# 2591  Y  2020-09-24 00:17:43+01F0339S; 2020-09-24 00:19...
# 4171  Y  2020-09-24 00:20:39+01F0339S; 2020-09-24 00:23...
# 4281  Y  2020-09-24 00:12:04+01F0339S; 2020-09-24 00:14...

# %%
total_data_rows = March_05.shape[0]+March_12.shape[0]+March_19.shape[0]+March_26.shape[0]
print('Total Rows of Data: '+str(total_data_rows))
# Out:
# Total Rows of Data: 12333

# %%
# Combine into one dataframe

df = pd.concat([March_05,March_12,March_19,March_26], ignore_index=True)
df.shape
# Out:
# (12333, 8)

# %%
# Save the cleaned raw data file as a csv file.

df.to_csv('Cleaned_Raw_Data.csv')

# %%
import re

example = df['7']
example
# Out:
# 0        2020-09-03 00:45:24+01F0339S; 2020-09-03 00:47...
# 1        2020-09-03 00:00:16+01F0339S; 2020-09-03 00:02...
# 2        2020-09-03 00:00:37+01F0339S; 2020-09-03 00:03...
# 3        2020-09-03 00:36:25+01F0339S; 2020-09-03 00:38...
# 4        2020-09-03 00:45:28+01F0339S; 2020-09-03 00:48...
# 5        2020-09-03 00:14:50+01F0339S; 2020-09-03 00:17...
# 6        2020-09-03 00:42:23+01F0339S; 2020-09-03 00:44...
# 7        2020-09-03 00:19:03+01F0339S; 2020-09-03 00:21...
# 8        2020-09-03 00:14:14+01F0339S; 2020-09-03 00:16...
# 9        2020-09-03 00:44:47+01F0339S; 2020-09-03 00:47...
# 10       2020-09-03 00:22:21+01F0339S; 2020-09-03 00:24...
# 11       2020-09-03 00:40:05+01F0339S; 2020-09-03 00:42...
# 12       2020-09-03 00:49:51+01F0339S; 2020-09-03 00:52...
# 13       2020-09-03 00:48:52+01F0339S; 2020-09-03 00:51...
# 14       2020-09-03 00:00:43+01F0339S; 2020-09-03 00:02...
# 15       2020-09-03 00:34:08+01F0339S; 2020-09-03 00:36...
# 16       2020-09-03 00:46:52+01F0339S; 2020-09-03 00:49...
# 17       2020-09-03 00:46:33+01F0339S; 2020-09-03 00:48...
# 18       2020-09-03 00:08:57+01F0339S; 2020-09-03 00:11...
# 19       2020-09-03 00:40:37+01F0339S; 2020-09-03 00:42...
# 20       2020-09-03 00:02:23+01F0339S; 2020-09-03 00:04...
# 21       2020-09-03 00:33:02+01F0339S; 2020-09-03 00:34...
# 22       2020-09-03 00:05:03+01F0339S; 2020-09-03 00:07...
# 23       2020-09-03 00:16:56+01F0339S; 2020-09-03 00:19...
# 24       2020-09-03 00:53:21+01F0339S; 2020-09-03 00:55...
# 25       2020-09-03 00:08:54+01F0339S; 2020-09-03 00:11...
# 26       2020-09-03 00:27:35+01F0339S; 2020-09-03 00:30...
# 27       2020-09-03 00:04:53+01F0339S; 2020-09-03 00:06...
# 28       2020-09-03 00:25:01+01F0339S; 2020-09-03 00:27...
# 29       2020-09-03 00:01:51+01F0339S; 2020-09-03 00:03...
#                                ...
# 12303    2020-09-24 23:15:19+01F0339S; 2020-09-24 23:17...
# 12304    2020-09-24 23:35:19+01F0339S; 2020-09-24 23:37...
# 12305    2020-09-24 23:06:03+01F0339S; 2020-09-24 23:08...
# 12306    2020-09-24 23:38:55+01F0339S; 2020-09-24 23:41...
# 12307    2020-09-24 23:49:32+01F0339S; 2020-09-24 23:52...
# 12308    2020-09-24 23:05:11+01F0339S; 2020-09-24 23:07...
# 12309    2020-09-24 23:17:02+01F0339S; 2020-09-24 23:19...
# 12310    2020-09-24 23:32:57+01F0339S; 2020-09-24 23:35...
# 12311    2020-09-24 23:30:54+01F0339S; 2020-09-24 23:32...
# 12312    2020-09-24 23:30:01+01F0339S; 2020-09-24 23:32...
# 12313    2020-09-24 23:32:55+01F0339S; 2020-09-24 23:35...
# 12314    2020-09-24 23:11:27+01F0339S; 2020-09-24 23:13...
# 12315    2020-09-24 23:16:03+01F0339S; 2020-09-24 23:18...
# 12316    2020-09-24 23:12:52+01F0339S; 2020-09-24 23:15...
# 12317    2020-09-24 23:03:55+01F0339S; 2020-09-24 23:06...
# 12318    2020-09-24 23:29:36+01F0339S; 2020-09-24 23:31...
# 12319    2020-09-24 23:02:17+01F0339S; 2020-09-24 23:04...
# 12320    2020-09-24 23:54:05+01F0339S; 2020-09-24 23:56...
# 12321    2020-09-24 23:22:46+01F0339S; 2020-09-24 23:24...
# 12322    2020-09-24 23:06:05+01F0339S; 2020-09-24 23:08...
# 12323    2020-09-24 23:14:52+01F0339S; 2020-09-24 23:17...
# 12324    2020-09-24 23:35:31+01F0339S; 2020-09-24 23:37...
# 12325    2020-09-24 23:40:44+01F0339S; 2020-09-24 23:42...
# 12326    2020-09-24 23:03:13+01F0339S; 2020-09-24 23:05...
# 12327    2020-09-24 23:25:45+01F0339S; 2020-09-24 23:28...
# 12328    2020-09-24 23:12:01+01F0339S; 2020-09-24 23:14...
# 12329    2020-09-24 23:32:45+01F0339S; 2020-09-24 23:35...
# 12330    2020-09-24 23:02:18+01F0339S; 2020-09-24 23:04...
# 12331    2020-09-24 23:35:09+01F0339S; 2020-09-24 23:38...
# 12332    2020-09-24 23:12:39+01F0339S; 2020-09-24 23:15...
# Name: 7, Length: 12333, dtype: object

# %%
# Calculate the latencies and time for each row and append it to the array to use for plotting.

latency = []
time_of_the_day = []

for i in range(len(example)):
    temp = re.split('[+]', example[i])
    t1 = temp[0]
    t2 = re.split('[;]', temp[4])[1]
    t1 = pd.to_datetime(t1)
    t2 = pd.to_datetime(t2)
    diff = pd.Timedelta(t2 - t1).total_seconds()
    latency.append(diff)
    time_of_the_day.append(t1)

# %%
# Check if the lengths of both arrays match to make sure the data is correct. Here, the index of each array represents the latency/time of its counterpart. For example, for index i, the latency is latency[i] and the time is time_of_the_day[i].

print('Length of Latency Array: '+str(len(latency)))
print('Length of Time Array: '+str(len(time_of_the_day)))
# Out:
# Length of Latency Array: 12333
# Length of Time Array: 12333

# %%
time_of_the_day[0]
# Out:
# Timestamp('2020-09-03 00:45:24')

# %%
date_df = pd.DataFrame({'TimeStamp':time_of_the_day})

# %%
date_df.head()
# Out:
#             TimeStamp
# 0 2020-09-03 00:45:24
# 1 2020-09-03 00:00:16
# 2 2020-09-03 00:00:37
# 3 2020-09-03 00:36:25
# 4 2020-09-03 00:45:28

# %%
# date_df['TimeStamp'] = pd.Series([val.time() for val in date_df['TimeStamp']])
time_only = pd.DatetimeIndex(date_df['TimeStamp']).time

# %%
time_only[0]
# Out:
# datetime.time(0, 45, 24)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(time_only, latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 Sep Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Since the above plot has a lot of noise with latency values greater than a certain threshold (~1500), any latency values greater than 1500 sohuld be removed. 

# Convert the lists into a dataframe to filter out rows which have latency values > 1500.
new_df = pd.DataFrame({'Time':time_only,'Latency':latency})

new_df.drop(new_df[(new_df['Latency']>1500)].index,inplace=True)

# %%
# Convert the new dataframe with latencies < 1500 into a list for plotting.

new_time = (new_df['Time'].to_list())
new_latency = (new_df['Latency'].to_list())

# %%
plt.figure(figsize=(15,10))
plt.scatter(new_time, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 Sep Thursdays')
plt.xlabel('Time of the day (hh:mm:ss)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=86400)
plt.show()

# %%
# Convert time to time in hours.

time_in_hours = []
for i in range(len(new_time)):
    temp = new_time[i].hour + new_time[i].minute/60
    time_in_hours.append(temp)

# %%
plt.figure(figsize=(15,10))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.title('Latency vs. Time of the day with limit 2020 Sep Thursdays')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24)
plt.show()

# %%
# Plot a polynomial regression line to fit the scatter plot.

x = time_in_hours
y = new_latency
# np.ployfit(x, y, N) where x is the x values, y is the y values, and N is the Nth ploynomial regression.
z = np.polyfit(x, y, 30)
p = np.poly1d(z)
xp = np.linspace(0,24)

plt.figure(figsize=(15,7))
plt.scatter(time_in_hours, new_latency, marker = 'x', s=0.5)
plt.plot(xp, p(xp), '-', marker = 'x', c = 'green')
plt.title('Latency vs. Time of the day for 2020 Sep Thursdays with latency limit at 1500s')
plt.xlabel('Time of the day (hours)')
plt.ylabel('Latency (s)')
plt.xlim(xmin=0)
plt.xlim(xmax=24) 
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
